# %%
import sys
sys.path.append("..")

# %%
from src.generator import CRMGenerator

# %%
generator = CRMGenerator(
    config_path="../",
    debug_flag=True
)

# %%
df = generator.generate(
    n=10_000
)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   comment      10000 non-null  str
#  1   service      10000 non-null  str
#  2   technology   10000 non-null  str
#  3   symptom      10000 non-null  str
#  4   reason       10000 non-null  str
#  5   degradation  10000 non-null  str
#  6   region       10000 non-null  str
#  7   template     10000 non-null  str
# dtypes: str(8)
# memory usage: 625.1 KB

# %%
df.comment.sample(10, axis=0).to_list()
# Out:
# ['PSTN отсутствует. Причина - проблема оборудования провайдера.',
#  'По услуге ШПД отсутствует. Причина - проблема оборудования провайдера.',
#  'Все-в-одном плохое качество. Причина - неисправность оборудования провайдера.',
#  'По услуге ШПД отсутствует. Причина - неисправность оборудования провайдера.',
#  'OTT есть проблемы. Причина - неисправность оборудования абонента.',
#  'доступ в Интернет (Wi-Fi) есть проблемы. Причина - неверная конфигурация ПО.',
#  'Интернет. GPON. авария на стороне провайдера.',
#  'доступ в Интернет. PON. падает сессия.',
#  'Все-в-одном. не работают приложения. Причина - проблема оборудования провайдера.',
#  'Интернет. падает сессия. Причина - авария на стороне провайдера.']

# %%
df.comment.to_csv('../data/text_corpus.csv', index=False)
