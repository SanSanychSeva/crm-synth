# %%
import sys
sys.path.append("..")

# %%
from src.generator import CRMGenerator

# %%
generator = CRMGenerator(
    config_path="../",
    seed=42,
    debug_flag=True
)

# %%
df = generator.generate(
    n=5_000
)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   comment      5000 non-null   str
#  1   service      5000 non-null   str
#  2   technology   5000 non-null   str
#  3   symptom      5000 non-null   str
#  4   reason       5000 non-null   str
#  5   degradation  5000 non-null   str
#  6   region       5000 non-null   str
#  7   template     5000 non-null   str
# dtypes: str(8)
# memory usage: 312.6 KB

# %%
df.comment.sample(10, axis=0).to_list()
# Out:
# ['По услуге Интернет плохое качество. Причина - авария на стороне провайдера.',
#  'По услуге IoT плохое качество. Причина - неисправность оборудования абонента.',
#  'доступ в Интернет есть проблемы. Причина - проблема оборудования провайдера.',
#  'OTT. не работают приложения. Причина - проблема абонентского оборудования.',
#  'Combo плохое качество. Причина - проблема оборудования провайдера.',
#  'На WiFi зарегистрировано: соединение отсутствует. Причина - неверная конфигурация ПО.',
#  'доступ в Интернет. нет авторизации. Причина - авария оборудования.',
#  'По услуге Интернет есть проблемы. Причина - проблема оборудования провайдера.',
#  'На PON зарегистрировано: нет соединения. Причина - авария оборудования.',
#  'Combo. не работают приложения. Причина - авария сети.']
