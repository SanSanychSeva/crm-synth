# %%
import sys
sys.path.append("..")

# %%
from src.generator import CRMGenerator

# %%
generator = CRMGenerator(
    config_path="../",
    seed=42
)

# %%
df = generator.generate(
    n=10000
)

df.head()
# Out:
#                                              comment   service technology  \
# 0  На ['GPON'] зарегистрировано: session_drop. Пр...     Combo       xPON
# 1  ['доступ в Интернет']. нет соединения. Причина...  Internet     Legacy
# 2  ['ШПД'] unavailable. Причина - проблема оборуд...  Internet       FTTx
# 3  ['ШПД']. Причина - проблема оборудования прова...  Internet       xDSL
# 4  Combo (['PON']) unavailable. Причина - ['авари...     Combo       xPON
#
#          symptom              reason  degradation    region template
# 0   session_drop  provider_equipment  unavailable  region_1      T05
# 1  no_connection  provider_equipment     degraded  region_3      T03
# 2        no_dhcp  provider_equipment  unavailable  region_2      T01
# 3  no_connection  provider_equipment     degraded  region_2      T09
# 4   session_drop     provider_outage  unavailable  region_3      T04

# %%
df.comment.sample(10, axis=0).to_list()
# Out:
# ["IoT (['xPON']) degraded. Причина - проблема абонентского оборудования.",
#  "Combo (['GPON']) unavailable. Причина - неисправность оборудования абонента.",
#  "['доступ в Интернет'] degraded. Причина - проблема оборудования провайдера.",
#  'OTT. application_failure. Причина - проблема абонентского оборудования.',
#  "CTV. FTTx. ['авария на стороне провайдера'].",
#  "['доступ в Интернет'] (Wi-Fi) unavailable. Причина - software_configuration.",
#  "['ШПД'] (Legacy) quality. Причина - проблема оборудования провайдера.",
#  'На Legacy зарегистрировано: соединение отсутствует. Причина - неисправность оборудования провайдера.',
#  "['доступ в Интернет'] (['PON']) unavailable. Причина - неисправность оборудования провайдера.",
#  "На ['PON'] зарегистрировано: application_failure. Причина - проблема оборудования провайдера."]
