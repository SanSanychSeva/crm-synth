# %%
import sys
sys.path.append("..")

# %%
from src.generator import CRMGenerator

# %%
generator = CRMGenerator(
    config_path="../",
    seed=42
)

# %%
df = generator.generate(
    n=1000
)

df.head()

# %%
generate(
    n=5_000_000,
    target_unique=1200
)
